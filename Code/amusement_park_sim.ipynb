# %% [markdown]
# # Notebook Intentions
#
# The purpose of this notebook is to simulate an amusement park.

# %%
from park import Park
from behavior_reference import BEHAVIOR_ARCHETYPE_PARAMETERS

# %% [markdown]
# ### Book Keeping
#
#     - Version: dictates the location performance graphs are stored
#     - Verbosity: controls much information is displayed during a simulation, increase to show more info
#     - Show Plots: controls whether park plots are displayed in this notebook
#     - RNG Seed: seeds random number generators to enforce identical results across runs/machines

# %%
VERSION = "50K Shapeland, FP+"
VERBOSITY = 0
SHOW_PLOTS = True
RNG_SEED = 5

# %% [markdown]
# ## Park
#
# The park contains Agents, Attractions and Activities.
#
# - Total Daily Agents: dictates how many agents visit the park within a day
# - Hourly Percent: dictates what percentage of Total Daily Agents visits the park at each hour
# - Perfect Arrivals: enforces that the exact amount of Total Daily Agents arrives during the day
# - Expedited Pass Ability Percent: percent of agents aware of expeditied passes
# - Expedited Threshold: acceptable queue wait time length before searching for an expedited pass
# - Expedited Limit: total number of expedited pass an agent can hold at any given time

# %%
TOTAL_DAILY_AGENTS = 50000
PERFECT_ARRIVALS = True
HOURLY_PERCENT = {
    "10:00 AM": 5,
    "11:00 AM": 15,
    "12:00 PM": 23,
    "1:00 PM": 18,
    "2:00 PM": 19,
    "3:00 PM": 10,
    "4:00 PM": 4,
    "5:00 PM": 1.25,
    "6:00 PM": 2.5,
    "7:00 PM": 1.25,
    "8:00 PM": 1,
    "9:00 PM": 0,
}
EXP_ABILITY_PCT = 0.7
EXP_THRESHOLD = 1
EXP_LIMIT = 3

# %% [markdown]
# ## Agents
#
# The park is populated by agents. Agents visit attractions and activities. They make decisions about where to go based on their preferences, the popularity of attractions and activities and waiting times. Each Agent has a behavioral archetype.
#
# - Ride Enthusiast: wants to stay for a long time, go on as many attractions as possible, doesn't want to visit activites, doesn't mind waiting
# - Ride Favorer: wants to go on a lot of attractions, but will vists activites occasionally, will wait for a while in a queue
# - Park Tourer: wants to stay for a long time and wants to see attractions and activities equally, reasonable about wait times
# - Park Visitor: doesn't want to stay long and wants to see attractions and activities equally, inpatient about wait times
# - Activity Favorer: doesn't want to stay long and prefers activities, reasonable about wait times
# - Activity Enthusiast: wants to visit a lot of activities, reasonable about wait times
#
# Archetypes can be tweaked and new archetypes can be added in `behavior_reference.py`.
#
# - Agent Archetype Distribution: dictates the probability an agent will have a particular behavioral archetype

# %%
# AGENT_ARCHETYPE_DISTRIBUTION = {
#     "ride_enthusiast": 15,
#     "ride_favorer": 15, # ride_fan?
#     "park_tourer": 25, # average_tourist?
#     "park_visitor": 25,
#     "activity_favorer": 15, # activity_fan
#     "activity_enthusiast": 5,
# }
AGENT_ARCHETYPE_DISTRIBUTION = {
    "ride_enthusiast": 15,
    "ride_fan": 15,
    "average_tourist": 45,
    "activity_fan": 15,
    "annual_passholder": 4,
    "entitled_annual_passholder": 1,
    "vlogger": 5
}

# %% [markdown]
# ## Attractions
#
# Attractions are essentially rides within a park.
#
# - Attractions: list of dictionaries that describe the attractions within the park
#     - Name: name of the attraction
#     - Run Time: How long the attraction take to run, in minutes
#     - Capacity: Maximium number of agents that can be on the attraction during a run
#     - Popularity: Value from 1-10 that describes how popular an attraction is with respect to other attractions
#     - Expedited Queue: Dictates whether the attraction has an expedited queue or not
#     - Expedited Queue Ratio: Dictates what percentage of attraction capacity is devoted to members of the expedited queue
#     - Child Eligible: Dictates whether children can ride the attraction
#     - Adult Eligible: Dictates whether adults can ride the attraction

# %%
ATTRACTIONS = [
    {
        "name": "Triangle",
        "alias": "Flight of Passage",
        "run_time": 5,
        "hourly_throughput": 1200,
        "popularity": 10,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Pentagon",
        "alias": "Kilimanjaro Safari",
        "run_time": 22,
        "hourly_throughput": 2200,
        "popularity": 8,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Square",
        "alias": "Expedition Everest",
        "run_time": 3,
        "hourly_throughput": 1800,
        "popularity": 9,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": False,
        "adult_eligible": True,
    },
    {
        "name": "Circle",
        "alias": "Navi River Journey",
        "run_time": 5,
        "hourly_throughput": 1100,
        "popularity": 4,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.7,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Hexagon",
        "alias": "Dinosaur",
        "run_time": 4,
        "hourly_throughput": 1800,
        "popularity": 4,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Heptagon",
        "alias": "Kali River Rapids",
        "run_time": 22,
        "hourly_throughput": 1600,
        "popularity": 4,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Trapezoid",
        "alias": "(Dinoland) Primeval Whirl?",
        "run_time": 2,
        "hourly_throughput": 900,
        "popularity": 3,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.7,
        "child_eligible": True,
        "adult_eligible": False,
    },
    {
        "name": "Oval",
        "alias": "(Tree of Life) Tough to be a Bug?",
        "run_time": 10,
        "hourly_throughput": 1800,
        "popularity": 3,
        "expedited_queue": False,
        "expedited_queue_ratio": 0.7,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        # PARAMS INFERRED FROM CHARTS (WIP)
        "name": "Rectangle",
        "alias": "?",
        "run_time": 4,
        "hourly_throughput": 1800,
        "popularity": 4,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        # PARAMS INFERRED FROM CHARTS (WIP)
        "name": "Octagon",
        "alias": "(Dinoland) Tricetatop Spin?",
        "run_time": 2, # https://touringplans.com/animal-kingdom/attractions/triceratop-spin
        "hourly_throughput": 600, # https://touringplans.com/animal-kingdom/attractions/triceratop-spin
        "popularity": 4,
        "expedited_queue": True,
        "expedited_queue_ratio": 0.8,
        "child_eligible": True,
        "adult_eligible": True,
    },
    {
        "name": "Diamond",
        "alias": "?",
        "run_time": 40,
        "hourly_throughput": 625,
        "popularity": 2,
        "expedited_queue": False,
        "expedited_queue_ratio": 0.7,
        "child_eligible": True,
        "adult_eligible": True,
    },
    # {
    #     # PARAMS INFERRED FROM CHARTS (WIP)
    #     "name": "Particularly Shapey Shape",
    #     "alias": "?",
    #     "run_time": 2,
    #     "hourly_throughput": 1800,
    #     "popularity": 4,
    #     "expedited_queue": False,
    #     "expedited_queue_ratio": 0.8,
    #     "child_eligible": True,
    #     "adult_eligible": True,
    # }
]

# %% [markdown]
# ## Activities
# Activities are everything to do within the park that isn't an attraction.
#
# - Activities: list of dictionaries that describe activities within the park
#     - Name: name of the activity
#     - Popularity: Value from 1-10 that describes how popular an activity is with respect to other activities
#     - Mean Time: The expected time agents will spend at an activity

# %%
ACTIVITIES = [
    {
      "name": "sightseeing",
      "popularity": 5,
      "mean_time": 5
    },
    {
      "name": "merchandise",
      "popularity": 5,
      "mean_time": 30
    },
    {
      "name": "food",
      "popularity": 5,
      "mean_time": 45
    },
    # INFERRED (WIP)
    {
      "name": "walking",
      "popularity": 5,
      "mean_time": 20
    },
    {
      "name": "bathroom",
      "popularity": 5,
      "mean_time": 5
    },
  ]

# %% [markdown]
# ## Plots
#
# Set the Y limit of plots

# %%
PLOT_RANGE = {
    "Attraction Queue Length": 1800,
    "Attraction Wait Time": 300,
    "Attraction Expedited Queue Length": 6000,
    "Attraction Expedited Wait Time": 500,
    "Activity Vistors": 20000,
    "Approximate Agent Distribution (General)": 1.0,
    "Approximate Agent Distribution (Specific)": 1.0,
    "Attraction Average Wait Times": 250,
    "Agent Attractions Histogram": 1.0,
    "Attraction Total Visits": 46000,
    "Expedited Pass Distribution": 150000,
    "Age Class Distribution": 20000,
}

# %% [markdown]
# ## Simulation
#
# Run the simulation here.

# %%
# Initialize Park
RNG_SEED = 5

park = Park(
    attraction_list=ATTRACTIONS,
    activity_list=ACTIVITIES,
    plot_range=PLOT_RANGE,
    random_seed=RNG_SEED,
    version=VERSION,
    verbosity=VERBOSITY
)

# Build Arrivals

park.generate_arrival_schedule(
    arrival_seed=HOURLY_PERCENT, 
    total_daily_agents=TOTAL_DAILY_AGENTS, 
    perfect_arrivals=PERFECT_ARRIVALS,
)

# Build Agents
park.generate_agents(
    behavior_archetype_distribution=AGENT_ARCHETYPE_DISTRIBUTION,
    exp_ability_pct=EXP_ABILITY_PCT,
    exp_wait_threshold=EXP_THRESHOLD,
    exp_limit=EXP_LIMIT
)

# Build Attractions + Activities
park.generate_attractions()
park.generate_activities()

# Pass Time
for _ in range(len(HOURLY_PERCENT.keys()) * 60):
    park.step()

# Save Parameters of Current Run
sim_parameters = {
    "VERSION": VERSION,
    "VERBOSITY": VERBOSITY,
    "SHOW_PLOTS": SHOW_PLOTS,
    "RNG_SEED": RNG_SEED,
    "TOTAL_DAILY_AGENTS": TOTAL_DAILY_AGENTS,
    "PERFECT_ARRIVALS": PERFECT_ARRIVALS,
    "HOURLY_PERCENT": HOURLY_PERCENT,
    "EXP_ABILITY_PCT": EXP_ABILITY_PCT,
    "EXP_THRESHOLD": EXP_THRESHOLD,
    "EXP_LIMIT": EXP_LIMIT,
    "AGENT_ARCHETYPE_DISTRIBUTION": AGENT_ARCHETYPE_DISTRIBUTION,
    "ATTRACTIONS": ATTRACTIONS,
    "ACTIVITIES": ACTIVITIES,
    "BEHAVIOR_ARCHETYPE_PARAMETERS": BEHAVIOR_ARCHETYPE_PARAMETERS,
}
park.write_data_to_file(
    data=sim_parameters, 
    output_file_path=f"{VERSION}/parameters", 
    output_file_format="json"
)

# Store + Print Data
park.make_plots(show=SHOW_PLOTS)
park.print_logs(N = 5)
#park.print_logs(selected_agent_ids = [778])
# Out:
# +--------------+---------------------+--------------+
# | Attraction   |   Average Wait Time | Queue Type   |
# |--------------+---------------------+--------------|
# | Triangle     |              169.93 | Expedited    |
# | Diamond      |                0.00 | Expedited    |
# | Square       |              147.21 | Expedited    |
# | Trapezoid    |              164.12 | Expedited    |
# | Oval         |                0.00 | Expedited    |
# | Pentagon     |              120.18 | Expedited    |
# | Circle       |              146.87 | Expedited    |
# | Hexagon      |               98.86 | Expedited    |
# | Octagon      |              189.58 | Expedited    |
# | Heptagon     |              103.34 | Expedited    |
# | Rectangle    |               98.12 | Expedited    |
# | Square       |              156.04 | Standby      |
# | Pentagon     |              110.93 | Standby      |
# | Octagon      |              229.01 | Standby      |
# | Diamond      |               83.22 | Standby      |
# | Triangle     |              260.45 | Standby      |
# | Hexagon      |               94.25 | Standby      |
# | Circle       |              117.00 | Standby      |
# | Oval         |               66.46 | Standby      |
# | Trapezoid    |              116.97 | Standby      |
# | Rectangle    |               93.34 | Standby      |
# | Heptagon     |               94.66 | Standby      |
# +--------------+---------------------+--------------+
# +----------+-----------------------------+
# | Metric   |   Total Attractions Visited |
# |----------+-----------------------------|
# | count    |                    50000.00 |
# | mean     |                        3.29 |
# | std      |                        3.36 |
# | min      |                        0.00 |
# | 25%      |                        1.00 |
# | 50%      |                        2.00 |
# | 75%      |                        5.00 |
# | max      |                       42.00 |
# +----------+-----------------------------+
# /Users/Aaron/programming/aaron-schroeder/shapeland/Code/park.py:336: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   ax = sns.barplot(data=df, x=x, y=y, hue=hue, ci=None, estimator=estimator)
# +--------------+----------+
# | Attraction   |   Visits |
# |--------------+----------|
# | Circle       |    12024 |
# | Diamond      |     5949 |
# | Heptagon     |    16526 |
# | Hexagon      |    19326 |
# | Octagon      |     6832 |
# | Oval         |    17841 |
# | Pentagon     |    23128 |
# | Rectangle    |    19313 |
# | Square       |    20166 |
# | Trapezoid    |     9952 |
# | Triangle     |    13597 |
# +--------------+----------+
# +--------------------+----------------+-------------+
# | Expedited Passes   |   Total Passes | Type        |
# |--------------------+----------------+-------------|
# |                    |         119585 | Distributed |
# |                    |         102007 | Redeemed    |
# +--------------------+----------------+-------------+
# +-------------+----------+----------------+
# | Age Class   |   Agents | Type           |
# |-------------+----------+----------------|
# |             |        0 | No Adult Rides |
# |             |        0 | No Child Rides |
# |             |    50000 | No Preference  |
# +-------------+----------+----------------+
# Agent ID: 40822
# Agent Archetype: activity_fan
# Agent arrived at park at time 308. Agent visited the activity food at time 308. Agent exited the activity food at time 349. Agent visited the activity food at time 350. Agent exited the activity food at time 391. Agent visited the activity sightseeing at time 392. Agent exited the activity sightseeing at time 396. Agent visited the activity bathroom at time 397. Agent exited the activity bathroom at time 401. Agent visited the activity merchandise at time 402. Agent exited the activity merchandise at time 429. Agent visited the activity bathroom at time 430. Agent exited the activity bathroom at time 434. Agent visited the activity merchandise at time 435. Agent exited the activity merchandise at time 462. Agent visited the activity walking at time 463. Agent exited the activity walking at time 481. Agent visited the activity bathroom at time 482. Agent exited the activity bathroom at time 486. Agent visited the activity bathroom at time 487. Agent exited the activity bathroom at time 491. Agent visited the activity bathroom at time 492. Agent exited the activity bathroom at time 496. Agent visited the activity food at time 497. Agent exited the activity food at time 538. Agent visited the activity walking at time 539. Agent exited the activity walking at time 557. Agent visited the activity merchandise at time 558. Agent exited the activity merchandise at time 585. Agent left park at 586.
#
# Agent ID: 16740
# Agent Archetype: ride_fan
# Agent arrived at park at time 154. Agent visited the activity merchandise at time 154. Agent exited the activity merchandise at time 187. Agent entered queue for Triangle at time 188. Agent boarded Triangle at time 425. Agent exited Triangle at time 430. Agent entered queue for Pentagon at time 431. Agent boarded Pentagon at time 682. Agent exited Pentagon at time 704. Agent left park at 705.
#
# Agent ID: 48613
# Agent Archetype: average_tourist
# Agent arrived at park at time 527. Agent visited the activity sightseeing at time 527. Agent exited the activity sightseeing at time 529. Agent entered queue for Square at time 530.
#
# Agent ID: 23496
# Agent Archetype: average_tourist
# Agent arrived at park at time 193. Agent visited the activity sightseeing at time 193. Agent exited the activity sightseeing at time 200. Agent picked up an expedited pass for Hexagon at time 201. The estimated expedited queue wait time is 39 minutes. Agent visited the activity walking at time 202. Agent exited the activity walking at time 233. Agent visited the activity merchandise at time 234. Agent exited the activity merchandise at time 240. Agent visited the activity walking at time 241. Agent exited the activity walking at time 242. Agent picked up an expedited pass for Circle at time 243. The estimated expedited queue wait time is 237 minutes. Agent picked up an expedited pass for Pentagon at time 244. The estimated expedited queue wait time is 130 minutes. Agent boarded Hexagon and redeemed their expedited queue pass at time 244. Agent exited Hexagon at time 248. Agent visited the activity food at time 249. Agent exited the activity food at time 320. Agent visited the activity sightseeing at time 321. Agent exited the activity sightseeing at time 328. Agent picked up an expedited pass for Heptagon at time 329. The estimated expedited queue wait time is 199 minutes. Agent visited the activity bathroom at time 330. Agent exited the activity bathroom at time 337. Agent visited the activity merchandise at time 338. Agent exited the activity merchandise at time 374. Agent boarded Pentagon and redeemed their expedited queue pass at time 374. Agent exited Pentagon at time 396. Agent picked up an expedited pass for Rectangle at time 397. The estimated expedited queue wait time is 215 minutes. Agent visited the activity sightseeing at time 398. Agent exited the activity sightseeing at time 405. Agent visited the activity food at time 406. Agent exited the activity food at time 460. Agent boarded Circle and redeemed their expedited queue pass at time 460. Agent exited Circle at time 465. Agent visited the activity sightseeing at time 466. Agent exited the activity sightseeing at time 473. Agent visited the activity merchandise at time 474. Agent exited the activity merchandise at time 506. Agent boarded Heptagon and redeemed their expedited queue pass at time 506. Agent exited Heptagon at time 528. Agent visited the activity sightseeing at time 529. Agent exited the activity sightseeing at time 536. Agent visited the activity bathroom at time 537. Agent exited the activity bathroom at time 544. Agent visited the activity merchandise at time 545. Agent exited the activity merchandise at time 588. Agent boarded Rectangle and redeemed their expedited queue pass at time 588. Agent exited Rectangle at time 592. Agent visited the activity bathroom at time 593. Agent exited the activity bathroom at time 600. Agent visited the activity bathroom at time 601. Agent exited the activity bathroom at time 608. Agent entered queue for Square at time 609.
#
# Agent ID: 45249
# Agent Archetype: average_tourist
# Agent arrived at park at time 366. Agent visited the activity food at time 366. Agent exited the activity food at time 418. Agent visited the activity walking at time 419. Agent exited the activity walking at time 442. Agent entered queue for Rectangle at time 443. Agent boarded Rectangle at time 632. Agent exited Rectangle at time 636. Agent visited the activity walking at time 637. Agent exited the activity walking at time 660. Agent entered queue for Square at time 661.
